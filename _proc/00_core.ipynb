# %% [raw]
# ---
# description: Fill in a module description here
# output-file: core.html
# title: core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(foo)
# Out:
# ---
#
# [source](https://github.com/scatterem/scatterem/blob/main/scatterem/core.py#L7){target="_blank" style="float:right; font-size:smaller"}
#
# ### foo
#
# >      foo ()

# %%
#| echo: false
#| output: asis
show_doc(say_hello)
# Out:
# ---
#
# [source](https://github.com/scatterem/scatterem/blob/main/scatterem/core.py#L10){target="_blank" style="float:right; font-size:smaller"}
#
# ### say_hello
#
# >      say_hello (to)
#
# Say hello to somebody

# %%
say_hello("Isaac")
# Out:
# 'Hello Isaac!'

# %%
assert say_hello("Hamel")=="Hello Hamel!"

# %%
from fastcore.test import *

# %%
test_eq(say_hello("Hamel"), "Hello Hamel!")
